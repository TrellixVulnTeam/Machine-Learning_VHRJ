# %% [markdown]
# ## Intro to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); ## adding semi colon prevents the display of []

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x,y);

# %%
#1st method
fig = plt.figure() #creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
#2st method
fig = plt.figure() #creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method(recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200,250]);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# O. Import matplotlib and get it ready for plotting
# %matplotlib inline
import matplotlib.pyplot as plt

#1.Prepare Data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 3. setup plot
fig, ax = plt.subplots(figsize = (10,10)) ## width & height

# plot data
ax.plot(x, y)

# customize plot
ax.set(title = "Simple Plot",
       xlabel = "x-axis",
       ylabel = "y-axis")

# save and show
fig.savefig("../Data/simple-plot.png")

# %%
## Making figures with numpy arrays

# %%
import numpy as np

# %%
#Creae some data
x = np.linspace(0, 10, 100) 
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use same data to make a scatter 
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax =plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond butter": 10,
                    "Peanut buutter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),height = nut_butter_prices.values())
ax.set(title = "Dan's Nut Butter Store",
       ylabel = "Price($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
## Histogram. Make some data
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x),
# Out:
# ((array([  3.,  10.,  53., 135., 273., 278., 163.,  66.,  17.,   2.]),
#   array([-3.76994733, -3.02507446, -2.2802016 , -1.53532874, -0.79045588,
#          -0.04558301,  0.69928985,  1.44416271,  2.18903557,  2.93390843,
#           3.6787813 ]),
#   <BarContainer object of 10 artists>),)

# %% [markdown]
# # Two options for subplots

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10,5))
# Plot to each different axis
ax.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots Option 2
fig, ax = plt.subplots(nrows = 2,
                       ncols = 2,
                       figsize = (10,5))
#Plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("../Data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
 ts = pd.Series(np.random.randn(1000),
    ...:                index=pd.date_range('1/1/2000', periods=1000))
    ...:

In [4]: ts = ts.cumsum()
    
In [5]: ts.plot()
##[5]: <matplotlib.axes._subplots.AxesSubplot at 0x7f4505e618d0>
# Out:
# <AxesSubplot:>

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# REmove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
## Let's plot the total sales
car_sales.plot(x="Sales Date", y="Total Sales");

# %%
## Reassign price column to int otherise get an error 
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price colums as numeric
car_sales.plot(x="Odometer (KM)", y ="Price", kind="scatter");

# %%
## Bar graph
x = np.random.rand(10, 4)
x

# Turn it into.a dataframe
df = pd.DataFrame(x, columns = ['a', 'b', 'c','d'])
df
# Out:
#           a         b         c         d
# 0  0.559076  0.026930  0.164959  0.997267
# 1  0.943519  0.462955  0.438368  0.678204
# 2  0.878666  0.604299  0.237406  0.986528
# 3  0.073775  0.252917  0.943517  0.510462
# 4  0.089124  0.506062  0.404751  0.698665
# 5  0.657893  0.333197  0.984160  0.475093
# 6  0.216094  0.375035  0.137473  0.897555
# 7  0.829829  0.709862  0.104105  0.716527
# 8  0.382944  0.940847  0.738826  0.378761
# 9  0.647503  0.408470  0.369318  0.022993

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales # always good to view your data frame.
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x = "Make", y = "Odometer (KM)", kind = "bar");

# %%
# Histograms
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=50);

# %%
# Let's try on another dataset
heart_disease = pd.read_csv("../Data/heart-disease.csv")

heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Histogram
heart_disease["age"].plot.hist(bins=30);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# * When doing quit plots, use pyplot method
# *When plotting something more advance, use OO method

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
##Pyplot method
over_50.plot(kind = 'scatter', 
             x = 'age',
             y = 'chol',
             c = 'target');

# %%
## Object Oriented (OO) method
fix, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind ='scatter', 
             x = 'age',
             y = 'chol',
             c = 'target',
            ax = ax);
ax.set_xlim([45, 100])
# Out:
# (45.0, 100.0)

# %%
## OO method
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50['age'],
                        y=over_50["chol"],
                        c=over_50["target"])

## Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel = "Age",
      ylabel = "Cholesterol");

## Add legend
ax.legend(*scatter.legend_elements(), title = "Target");

## Add horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle= '--');

# %%
## Adding a subplot of chol, age, and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10))

## Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

##Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

##Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

##Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");



## Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                      c=over_50["target"])

##Customize ax1
ax1.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
        ylabel="talach")

##Add a meanline
ax1.axhline(y=over_50["chol"].mean(),
            linestyle="--");

## Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib plts and styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
## Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.87586238,  0.51508878,  0.94413032,  0.0521096 ],
#        [ 0.03389332,  0.82602976, -0.54512649,  0.06020628],
#        [ 1.62220417, -0.99016485, -0.1862277 , -0.65140253],
#        [-1.09318201,  1.39087453, -1.22711032,  1.53584069],
#        [-2.95609991,  1.04216766, -1.18817018,  0.20277377],
#        [ 0.61548893,  0.5414128 , -0.90741669, -0.12891468],
#        [-0.5815692 ,  0.18097015,  0.47236548,  1.17776061],
#        [-1.75592774,  1.28116186,  1.40988189, -0.14423705],
#        [-0.2348738 ,  1.92719532, -1.71942946,  0.76539139],
#        [-0.1599406 ,  0.1511986 ,  0.93286941, -0.45779394]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.875862  0.515089  0.944130  0.052110
# 1  0.033893  0.826030 -0.545126  0.060206
# 2  1.622204 -0.990165 -0.186228 -0.651403
# 3 -1.093182  1.390875 -1.227110  1.535841
# 4 -2.956100  1.042168 -1.188170  0.202774
# 5  0.615489  0.541413 -0.907417 -0.128915
# 6 -0.581569  0.180970  0.472365  1.177761
# 7 -1.755928  1.281162  1.409882 -0.144237
# 8 -0.234874  1.927195 -1.719429  0.765391
# 9 -0.159941  0.151199  0.932869 -0.457794

# %%
ax = df.plot(kind='bar');

# %%
## Customize our plot with the set() method
ax = df.plot(kind="bar")
##Add some labels and a title
ax.set(title="Random Number Bar graph from DataFrame",
       xlabel="Row number",
       ylabel="Radm nbr");
ax.legend().set_visible(True)

# %%
# Set the Style
plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(10, 6))

scater = ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"],
                   cmap="winter") ## change the color scheme

ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol")


#Add legend
ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(),
          linestyle='--');

# %%
## Customize the x and y axis 

## Adding a subplot of chol, age, and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True)

## Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

##Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol")

#Change the x-axis limitations
ax0.set_xlim([50, 80])

##Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

##Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");



## Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                      c=over_50["target"],
                     cmap="winter")

##Customize ax1
ax1.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
        ylabel="Max Heart Rate")
# Change ax1 the x-axis limits
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])
##Add legent to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

##Add a meanline
ax1.axhline(y=over_50["chol"].mean(),
            linestyle="--");

## Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
## save by save image as.... or
fig.savefig("heart disease plot saved with code.png")
